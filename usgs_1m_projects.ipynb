# %%
# %matplotlib inline
import geopandas as gpd

df = gpd.read_file('../dem/FESM_1m.gpkg')

# %%
df[df['proj_name'].str.startswith('IL')].plot(figsize=(20,20))

# %%
df[df['proj_name'].str.startswith('IL')].head(50)
# Out:
#      pmethod               s_date  zunit  \
# 12         7  2014-03-20T00:00:00      1
# 13         7  2014-03-20T00:00:00      1
# 23         7  2017-11-19T00:00:00      1
# 45         7  2015-04-26T00:00:00      1
# 55         7  2009-03-20T00:00:00      1
# 56         7  2013-11-23T00:00:00      1
# 58         7  2008-04-16T00:00:00      1
# 64         7  2008-04-16T00:00:00      1
# 66         7  2009-05-12T09:27:24      1
# 72         7  2008-04-16T00:00:00      1
# 81         7  2008-04-16T00:00:00      1
# 88         7  2009-03-20T00:00:00      1
# 99         7  2017-11-19T00:00:00      1
# 118        7  2009-03-20T00:00:00      1
# 122        7  2009-03-20T00:00:00      1
# 125        7  2009-03-20T14:22:26      1
# 128        7  2009-03-20T00:00:00      1
# 160        7  2014-04-12T00:00:00      1
# 173        7  2014-03-23T00:00:00      1
# 242        7  2014-12-03T00:00:00      1
# 336        7  2017-04-07T00:00:00      1
#
# ...
